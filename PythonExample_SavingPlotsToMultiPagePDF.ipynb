# %% [markdown]
# <a href="https://colab.research.google.com/github/bingsen-wang/Python-Examples/blob/main/PythonExample_SavingPlotsToMultiPagePDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><h1><b>Save Plots to Multi-Page PDF File</h1></b>
#
# Dr. Bingsen Wang
#
# 8/13/2024
# </center>

# %% [markdown]
# #Python Code
# The Python code illustrates save plots to a multi-page PDF file.

# %%
from matplotlib.backends.backend_pdf import PdfPages
from numpy import pi,sin,linspace
import matplotlib.pyplot as plt
pdf = PdfPages("test.pdf")
theta = linspace(0,2*pi,100)
plt.figure(figsize=(16,9))
for k in range(8):
  plt.plot(theta,sin(theta+2*pi/8*k),lw=2)
  pdf.savefig()
pdf.close()
